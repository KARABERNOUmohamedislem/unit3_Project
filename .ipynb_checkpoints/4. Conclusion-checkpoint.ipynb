# %% [markdown]
# <img src="Logo.png" width="100" align="left"/>
#
# # <center> Unit 3 Project </center>
# #  <center> Fourth section : Conclusion </center>
#
#
# In this notebook you will be comparing the results of the two methods we used on the created testset. That is said: you will compare the results to the clustering with the results of the classification on the same test test and provide insights and explanation about the observed behaviour.

# %% [markdown]
# For this final task you will need to :
# 1. Load the testset data that you created all along this project
# 2. For each cluster provide percentages about each actual/ predicted class contained with this cluster. Eg : cluster N°2 : is made of ( 50% class 2 and 50% class 3 ) from actual labels and ( 40 % predicted class 2 and 40% predicted class 3 + 20% predicted class 1)
# The above is just an example and is far away from the actual situation.
#
# 3. Explain the behaviour and provide isights about it

# %% [markdown]
# ## 1.  Load the data:

# %%
import pandas as pd

# %%
# To-Do : load the test summary data 
df = pd.read_csv("test_summary.csv")

# %%
df.head()
# Out:
#     ID  Age  Sex   ALB    ALP   ALT   AST   BIL    CHE  CHOL    CREA    GGT  \
# 0  552   36    1  44.0   32.9   9.4  32.0  14.0  11.42  5.73    68.6   40.6
# 1  258   56    1  49.5   56.3  22.1  24.9  11.5   8.56  4.69    91.0   14.7
# 2  592   46    1  35.0  109.6   2.3  19.2  11.0   7.10  4.10  1079.1  105.6
# 3  207   51    1  38.0   54.8  23.8  28.6  13.5   6.33  4.65    99.0   18.3
# 4  294   64    1  46.0   75.9  34.8  30.6  10.8   9.43  6.69    81.0   53.7
#
#    PROT  Category  Predicted_class  cluster
# 0  70.9         2                2        3
# 1  69.6         0                0        3
# 2  69.1         4                0        0
# 3  66.4         0                0        3
# 4  70.7         0                0        4

# %%
df.shape
# Out:
# (123, 16)

# %% [markdown]
# ## 2. Analysis:

# %%
# To-Do create a summary about each cluster : 
# percentages of each target (actual Category) within each cluster 
# + Percentages of each predicted class within the cluster 
# results should be something like : 
# For clusterk : {'true_class0_percetage': 0.0,
#                 'true_class1_percetage': 0.0,
#                  'true_class2_percetage': 0.0,
#                   'true_class3_percetage': 0.0,
#                   'true_class4_percetage': 0.0,
#                   'predicted_class0_percetage': 0.0,
#                   'predicted_class1_percetage': 0.0,
#                   'predicted_class2_percetage': 0.0,
#                   'predicted_class3_percetage': 0.0,
#                    'predicted_class4_percetage': 0.0}
clusters = []
for i in range(5):
    clusters.append({})
    cluster_count = len(df[df.cluster == i])
    if cluster_count == 0:
        clusters[i]["true_class0_percetage"] = 0
        clusters[i]["true_class1_percetage"] = 0
        clusters[i]["true_class2_percetage"] = 0
        clusters[i]["true_class3_percetage"] = 0
        clusters[i]["true_class4_percetage"] = 0
        clusters[i]["predicted_class0_percetage"] = 0
        clusters[i]["predicted_class1_percetage"] = 0
        clusters[i]["predicted_class2_percetage"] = 0
        clusters[i]["predicted_class3_percetage"] = 0
        clusters[i]["predicted_class4_percetage"] = 0
    else:
        clusters[i]["true_class0_percetage"] = len(df[(df.cluster == i) & (df.Category == 0)]) / cluster_count
        clusters[i]["true_class1_percetage"] = len(df[(df.cluster == i) & (df.Category == 1)]) / cluster_count
        clusters[i]["true_class2_percetage"] = len(df[(df.cluster == i) & (df.Category == 2)]) / cluster_count
        clusters[i]["true_class3_percetage"] = len(df[(df.cluster == i) & (df.Category == 3)]) / cluster_count
        clusters[i]["true_class4_percetage"] = len(df[(df.cluster == i) & (df.Category == 4)]) / cluster_count
        clusters[i]["predicted_class0_percetage"] = len(df[(df.cluster == i) & (df.Predicted_class == 0)]) / cluster_count
        clusters[i]["predicted_class1_percetage"] = len(df[(df.cluster == i) & (df.Predicted_class == 1)]) / cluster_count
        clusters[i]["predicted_class2_percetage"] = len(df[(df.cluster == i) & (df.Predicted_class == 2)]) / cluster_count
        clusters[i]["predicted_class3_percetage"] = len(df[(df.cluster == i) & (df.Predicted_class == 3)]) / cluster_count
        clusters[i]["predicted_class4_percetage"] = len(df[(df.cluster == i) & (df.Predicted_class == 4)]) / cluster_count
        
clusters
# Out:
# [{'true_class0_percetage': 0.0,
#   'true_class1_percetage': 0.0,
#   'true_class2_percetage': 0.0,
#   'true_class3_percetage': 0.0,
#   'true_class4_percetage': 1.0,
#   'predicted_class0_percetage': 0.5,
#   'predicted_class1_percetage': 0.0,
#   'predicted_class2_percetage': 0.0,
#   'predicted_class3_percetage': 0.0,
#   'predicted_class4_percetage': 0.5},
#  {'true_class0_percetage': 0.0,
#   'true_class1_percetage': 0.0,
#   'true_class2_percetage': 0.2857142857142857,
#   'true_class3_percetage': 0.0,
#   'true_class4_percetage': 0.7142857142857143,
#   'predicted_class0_percetage': 0.0,
#   'predicted_class1_percetage': 0.0,
#   'predicted_class2_percetage': 0.14285714285714285,
#   'predicted_class3_percetage': 0.14285714285714285,
#   'predicted_class4_percetage': 0.7142857142857143},
#  {'true_class0_percetage': 0.0,
#   'true_class1_percetage': 0.0,
#   'true_class2_percetage': 1.0,
#   'true_class3_percetage': 0.0,
#   'true_class4_percetage': 0.0,
# ...

# %% [markdown]
# ## 3. Explanations and isights :

# %%
# in this section you should display analysis about each cluster and comment those one by one 
import matplotlib.pyplot as plt

# %% [markdown]
# ### First cluster

# %%
tab = list(clusters[0].values())
true_classes = [i for i in tab[0:5]]
predicted_classes = [i for i in tab[5:10]]


f, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,5)) 
ax1.bar(range(5),true_classes)

ax1.set_title('True classes')

ax2.bar(range(5),predicted_classes)
ax2.set_title('Predicted classes')

plt.ylim(0, 1) 
plt.show()

# %% [markdown]
# #### Comments
# - we can see that the first cluster contains only rows from the fourth category (we may say that the first cluster represents the fourth category, but we will see the results of the other clusters).
# - also we can see that the predicted classes are 50% true (it may be due the small number of cluster 0 rows).

# %%
df[df.cluster == 0]
# Out:
#      ID  Age  Sex   ALB    ALP  ALT   AST   BIL   CHE  CHOL    CREA    GGT  \
# 2   592   46    1  35.0  109.6  2.3  19.2  11.0  7.10  4.10  1079.1  105.6
# 66  607   49    0  33.0  190.7  1.2  36.3   7.0  6.92  3.82   485.9  112.0
#
#     PROT  Category  Predicted_class  cluster
# 2   69.1         4                0        0
# 66  58.5         4                4        0

# %% [markdown]
# ### Second cluster

# %%
tab = list(clusters[1].values())
true_classes = [i for i in tab[0:5]]
predicted_classes = [i for i in tab[5:10]]


f, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,5)) 
ax1.bar(range(5),true_classes)

ax1.set_title('True classes')

ax2.bar(range(5),predicted_classes)
ax2.set_title('Predicted classes')

plt.ylim(0, 1) 
plt.show()

# %% [markdown]
# #### Comments
# - Here, we see that the second cluster is formed of 70% of fourth category rows and 30% of second category rows (here we see that the first cluster doesn't necessarly represent the fourth category).
# - Here, the predicted classes are approximately 85% true (70% of the fourth category and 15% of the second category).

# %%
df[df.cluster == 1]
# Out:
#       ID  Age  Sex   ALB   ALP   ALT    AST    BIL    CHE  CHOL   CREA    GGT  \
# 24   590   45    1  29.0  11.3   7.1  101.9   31.0   1.73  3.71   76.7   65.6
# 39   544   25    1  42.0  38.2  63.3  187.7   14.0   6.00  4.28   66.9   40.2
# 55   601   59    1  27.0  73.8   4.0   65.2  209.0   2.47  3.61   71.7   28.5
# 62   606   42    0  33.0  79.0   3.7   55.7  200.0   1.72  5.16   89.1  146.3
# 72   600   59    1  36.0  49.7   5.2  110.1   37.0   2.29  3.68  118.2   56.9
# 94   558   51    1  43.0  37.2  21.4  132.8    5.0  10.12  5.23   76.2   76.4
# 100  602   59    1  31.0  86.3   5.4   95.4  117.0   1.57  3.51   60.5   53.6
#
#      PROT  Category  Predicted_class  cluster
# 24   70.0         4                4        1
# 39   70.5         2                2        1
# 55   60.6         4                4        1
# 62   69.9         4                4        1
# 72   74.8         4                4        1
# 94   76.7         2                3        1
# ...

# %% [markdown]
# ### Third cluster

# %%
tab = list(clusters[2].values())
true_classes = [i for i in tab[0:5]]
predicted_classes = [i for i in tab[5:10]]


f, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,5)) 
ax1.bar(range(5),true_classes)

ax1.set_title('True classes')

ax2.bar(range(5),predicted_classes)
ax2.set_title('Predicted classes')

plt.ylim(0, 1) 
plt.show()

# %% [markdown]
# #### Comments
# - Here, we see that the second cluster is formed of 100% of the second category rows in his test set.
# - Here, the predicted classes are approximately 0% true (this may be due to the small number of the third cluster rows in the test set).

# %%
df[df.cluster == 2]
# Out:
#      ID  Age  Sex   ALB   ALP   ALT   AST   BIL   CHE  CHOL   CREA    GGT  \
# 36  560   58    1  43.0  99.1  12.2  63.2  13.0  5.95  6.15  147.3  491.0
#
#     PROT  Category  Predicted_class  cluster
# 36  65.6         2                4        2

# %% [markdown]
# ### Forth cluster

# %%
tab = list(clusters[3].values())
true_classes = [i for i in tab[0:5]]
predicted_classes = [i for i in tab[5:10]]


f, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,5)) 
ax1.bar(range(5),true_classes)

ax1.set_title('True classes')

ax2.bar(range(5),predicted_classes)
ax2.set_title('Predicted classes')

plt.ylim(0, 1) 
plt.show()

# %% [markdown]
# #### Comments
# - Here, we see that the second cluster is formed of 90% of the zeroth category rows and a small pecentage of the other categories.
# - Here, the predicted classes are approximately +90% true.

# %%
df[df.cluster == 3]
# Out:
#       ID  Age  Sex   ALB   ALP   ALT   AST   BIL    CHE  CHOL   CREA   GGT  \
# 0    552   36    1  44.0  32.9   9.4  32.0  14.0  11.42  5.73   68.6  40.6
# 1    258   56    1  49.5  56.3  22.1  24.9  11.5   8.56  4.69   91.0  14.7
# 3    207   51    1  38.0  54.8  23.8  28.6  13.5   6.33  4.65   99.0  18.3
# 5     13   33    1  36.3  78.6  23.6  22.0   7.0   8.56  5.38   78.0  19.4
# 6     89   39    1  37.5  80.2  32.6  25.3   2.7   9.30  6.85   72.0  27.5
# ..   ...  ...  ...   ...   ...   ...   ...   ...    ...   ...    ...   ...
# 113   19   33    1  36.6  57.1  38.9  40.3  24.9   9.62  5.50  112.0  27.6
# 116  106   41    1  53.3  79.0  29.5  28.5  14.1   7.96  5.90   87.0  33.8
# 117  502   57    0  38.6  80.9  33.1  26.7   6.5   6.45  5.10   59.0  11.3
# 118  470   52    0  51.5  81.8  26.3  20.6   7.8   6.74  5.90   88.0  16.3
# 119  469   52    0  40.2  89.7  26.8  19.1   6.9   9.10  7.04   75.0  41.6
#
#      PROT  Category  Predicted_class  cluster
# ...

# %% [markdown]
# ### Fifth cluster

# %%
tab = list(clusters[4].values())
true_classes = [i for i in tab[0:5]]
predicted_classes = [i for i in tab[5:10]]


f, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,5)) 
ax1.bar(range(5),true_classes)

ax1.set_title('True classes')

ax2.bar(range(5),predicted_classes)
ax2.set_title('Predicted classes')

plt.ylim(0, 1) 
plt.show()

# %% [markdown]
# #### Comments
# - Here, we see that the second cluster is formed of 68% of the zeroth category rows, +20% of the third category and the rest of the first and fourth category.
# - Here, the predicted classes are approximately +90% true.

# %%
df[df.cluster == 4]
# Out:
#       ID  Age  Sex        ALB        ALP    ALT    AST   BIL    CHE      CHOL  \
# 4    294   64    1  46.000000  75.900000   34.8   30.6  10.8   9.43  6.690000
# 21   584   56    0  39.000000  37.841667   42.0   34.0  10.0   7.75  5.000000
# 26   281   60    1  45.200000  89.400000   38.6   27.2   8.6   5.19  6.010000
# 27   566   40    1  39.000000  43.100000   23.8  114.7  11.0   9.64  4.200000
# 32    95   40    1  41.400000  67.500000   59.8   36.8   7.3   4.18  6.020000
# 33   539   74    1  20.300000  84.000000   22.8   43.0   5.7   4.91  3.190000
# 40   308   67    1  44.800000  72.800000   39.4   28.4  23.3   7.84  7.020000
# 52   195   50    1  40.000000  87.800000   87.5   52.6   4.8   8.70  6.460000
# 63    24   34    1  43.400000  46.100000   97.8   46.2  11.3   7.99  3.620000
# 67   604   65    1  41.620195  93.220833   40.0   54.0  13.0   7.50  4.008571
# 87   582   49    0  39.000000  37.841667   46.0   39.0   9.0  10.21  3.100000
# ...

# %% [markdown]
# ## 4. Conclusion:
#
# Explain your findings and provide reasons for the behaviour.

# %% [markdown]
# Using only the test set, can't really help us see if the clustering task was successfull or not, because in some cases we only have few examples of the cluster in the test set (such as the third cluster with only one row). But we can conclude some results:
# - The results of the clustering task aren't very representative, since we have for example the fourth and fifth cluster that contain both majorly the zeroth category rows.
# - The problem might be due to the number of features (since we didn't do a feature selection task).
